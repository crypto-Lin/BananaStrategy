# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.figure(figsize = (18,9))

# %%
df = pd.read_csv('./dataset/position_info.csv')
df.head()
# Out:
#    Unnamed: 0    datetime  position_fund  short_position_fund        fund  \
# 0           1  2018-06-04       930000.0            9067155.0   9997155.0
# 1           2  2018-06-05      1852049.0            8169102.0  10021151.0
# 2           3  2018-06-06      2473021.0            7550918.0  10023939.0
# 3           4  2018-06-07      2461329.0            7549200.0  10010529.0
# 4           5  2018-06-08      3275158.0            6699918.0   9975076.0
#
#          dr
# 0 -0.000285
# 1  0.002400
# 2  0.000278
# 3 -0.001338
# 4 -0.003542

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
plt.figure(figsize = (18,9))
plt.plot(df['datetime'] ,df['fund'],df['datetime'], df['short_position_fund'])
# Out:
# [<matplotlib.lines.Line2D at 0x7fe7a3813650>,
#  <matplotlib.lines.Line2D at 0x7fe7a3ce0250>]

# %%
plt.figure(figsize = (18,9))
plt.plot(df['datetime'], df['short_position_fund'])
